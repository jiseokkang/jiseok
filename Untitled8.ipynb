# %% [markdown]
# <a href="https://colab.research.google.com/github/jiseokkang/jiseok/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import networkx as nx
K = np.loadtxt('/content/sample_data/social.csv', delimiter=",")
G = nx.to_networkx_graph(K)
nx.draw(G, with_labels=True, node_color='yellow', edge_color='red')
